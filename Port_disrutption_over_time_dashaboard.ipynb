# %% [markdown]
# <a href="https://colab.research.google.com/github/thisisZAQ/Port-Dashboard/blob/main/Port_disrutption_over_time_dashaboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_liner = pd.read_csv('/content/drive/MyDrive/liner_connectivity.csv')
df_liner.head()
# Out:
#   economy_label quarter_label  index_value missingvalue
# 0       Albania       Q4 2006         5.01          NaN
# 1       Albania       Q1 2007         5.48          NaN
# 2       Albania       Q2 2007         5.48          NaN
# 3       Albania       Q3 2007         5.04          NaN
# 4       Albania       Q4 2007         5.19          NaN

# %%
st.title("Global Port Liner Connectivity Dashboard")
# Load data
@st.cache_data
def load_data():
  port_liner = pd.read_csv('/content/drive/MyDrive/port_liner.csv')
  df_liner = pd.read_csv('/content/drive/MyDrive/liner_connectivity.csv')
  return port_liner, df_liner
df_liner, port_liner = load_data()

df_liner['quarter_label'] = pd.to_datetime(df_liner['quarter_label'].str.replace(r'(Q\d) (\d+)', r'\2-\1'), errors='coerce')
port_liner['quarter_label'] = pd.to_datetime(port_liner['quarter_label'].str.replace(r'(Q\d) (\d+)', r'\2-\1'), errors='coerce')

# Sidebar filters
st.subheader('Raw data')
st.write(df_liner)
# Out:
# 2025-06-01 16:00:11.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-01 16:00:11.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-01 16:00:11.386 No runtime found, using MemoryCacheStorageManager
# <ipython-input-23-a29a9aa1c9e6>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_liner['quarter_label'] = pd.to_datetime(df_liner['quarter_label'].str.replace(r'(Q\d) (\d+)', r'\2-\1'), errors='coerce')
# <ipython-input-23-a29a9aa1c9e6>:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...
